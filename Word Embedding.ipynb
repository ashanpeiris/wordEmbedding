# %%
import re
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from gensim.test.utils import datapath
import fasttext
import fasttext.util

# %%
with open('sinhala_stopwords.txt', encoding="utf8") as stp:
    stopwords = stp.read()
stp.close()

# %%
all_sentences = []
text_file = open('sinhala.txt', 'r', encoding="utf8")
for sentence in text_file:
    word_list = re.sub(r'[.,"\'-?:!;\n]', '', sentence)
    word_list = word_tokenize(word_list)
    parsed = []
    for word in word_list:
        if word not in stopwords:
            parsed.append(word)
    all_sentences.append(parsed)
text_file.close()

# %%
test_words = ['යුතු','මුදල්','දින','සඳහන්','නිවාඩු','ලේකම්','කවරේද','ජාතික','වැටුප්','ඉදිරිපත්']

# %%
word2vec_skipgram = Word2Vec(all_sentences, min_count=2, sg=0)
for word in test_words:
    sim_words = word2vec_skipgram.wv.most_similar(word)
    print(word)
    print(*sim_words, sep="\n")
    print()
# Out:
# යුතු
# ('යුතුය', 0.9641897678375244)
# ('හැකි', 0.9415063261985779)
# ('යුත්තේ', 0.930286705493927)
# ('භා', 0.9099206328392029)
# ('යුතුවේ', 0.9034984111785889)
# ('සහතික', 0.8958048224449158)
# ('වැය', 0.8953712582588196)
# ('තීරණය', 0.8946816921234131)
# ('වාර්තාව', 0.8940847516059875)
# ('ලිපිවල', 0.8905689716339111)
#
# මුදල්
# ('ප්\u200dරතිපාදනය', 0.9473763108253479)
# ('ශ\u200d්\u200dරමය', 0.9105315804481506)
# ('වියදම්', 0.907948911190033)
# ('පියවීම', 0.9063883423805237)
# ('ඉල්ලීම්', 0.9027177691459656)
# ('ඔබගේ', 0.9021285772323608)
# ('ජේදය', 0.9013384580612183)
# ('එකී', 0.9011407494544983)
# ('දෑ', 0.9009097814559937)
# ('රෙගුලාසිවලට', 0.8988077044487)
#
# දින
# ('ලැබ', 0.9714817404747009)
# ('මස', 0.9707421064376831)
# ('පළ', 0.9686501026153564)
# ('අත්සන්', 0.9587963819503784)
# ('ලැබුවාවූ', 0.9539610147476196)
# ('පළකරනු', 0.9485043883323669)
# ('පත\u200d්\u200dරයේ', 0.9448172450065613)
# ('ඔක්තෝබර්', 0.9430589079856873)
# ('ඉදිරිපත්කරන', 0.9330236911773682)
# ('පත්\u200dරයේ', 0.9326760172843933)
#
# සඳහන්
# ('වගන්තිවල', 0.9116080403327942)
# ('සීමාවන්ට', 0.9037732481956482)
# ('දන්නෙහිද', 0.9032076001167297)
# ('දැක්වෙන', 0.9031282663345337)
# ('දැක්වේ', 0.9031201004981995)
# ('පිළිගන්නෙහිද', 0.8962474465370178)
# ('යන්නත්', 0.8960840106010437)
# ('කරුණු', 0.8913792967796326)
# ('කරුණුවලට', 0.8859487771987915)
# ('යන්න', 0.8855193257331848)
#
# නිවාඩු
# ('ඔහුට', 0.9481646418571472)
# ('ණය', 0.9344427585601807)
# ('රහිත', 0.9337424039840698)
# ('ගන්නා', 0.9268468618392944)
# ('වැටුප', 0.9261000156402588)
# ('ඔහු', 0.9241814613342285)
# ('අස්වීමට', 0.9239171743392944)
# ('සම්පූර්ණ', 0.9213744401931763)
# ('වැටුප්', 0.9210124015808105)
# ('එසේ', 0.9208723902702332)
#
# ලේකම්
# ('දිසාපති', 0.9770844578742981)
# ('දිස්ත්\u200dරික්', 0.973021388053894)
# ('කොට්ඨාස', 0.9665907025337219)
# ('කාර්යාලවල', 0.9655012488365173)
# ('ප්\u200dරාදේශීය', 0.9653343558311462)
# ('කාර්යාලය', 0.9627174735069275)
# ('කාර්යාලයේ', 0.9623846411705017)
# ('කොට්ඨාසය', 0.9598779678344727)
# ('කාර්යාල', 0.9590880870819092)
# ('කොට්ඨාසයේ', 0.9507027268409729)
#
# කවරේද
# ('යන්න', 0.9651926755905151)
# ('පියවර', 0.9535661339759827)
# ('යන්නත්', 0.9462414383888245)
# ('පොරොන්දුවක්', 0.9462337493896484)
# ('තිබේද', 0.9428250789642334)
# ('එතුමා', 0.9425581693649292)
# ('කොපමණද', 0.9419369697570801)
# ('කරන්නේද', 0.9416860342025757)
# ('දිනය', 0.9376969337463379)
# ('නිර්ණායකයන්', 0.9366461634635925)
#
# ජාතික
# ('ඒකාබද්ධතා', 0.964019238948822)
# ('කොමිෂන්', 0.9572102427482605)
# ('සංවර්ධන', 0.9528524875640869)
# ('කළමනාකරණ', 0.951421320438385)
# ('සමාජ', 0.9439637064933777)
# ('කොමසාරිස්', 0.942994236946106)
# ('සභාවේ', 0.9382344484329224)
# ('සභාව', 0.9376322031021118)
# ('විෂය', 0.9349139928817749)
# ('තාක්ෂණ', 0.934719979763031)
#
# වැටුප්
# ('විශ්\u200dරාම', 0.9454441070556641)
# ('නිවාඩු', 0.9210124015808105)
# ('රහිත', 0.9126954674720764)
# ('ගෙවීමකින්', 0.9121531248092651)
# ('වර්ධක', 0.888526976108551)
# ('සේවානියුක්තයන්ගේ', 0.8882551193237305)
# ('වැටුප', 0.8798697590827942)
# ('පරිමාණයක්', 0.8761590123176575)
# ('හිඟ', 0.8760650157928467)
# ('පරිමාණයේ', 0.8677566647529602)
#
# ඉදිරිපත්
# ('තීරණය', 0.9707667231559753)
# ('ලදින්', 0.9673532843589783)
# ('නිකුත්', 0.9599145650863647)
# ('බලධරයා', 0.9514632225036621)
# ('නියමය', 0.9503617882728577)
# ('සහතික', 0.948961079120636)
# ('අවලංගු', 0.9470492005348206)
# ('සභාභිමුඛ', 0.9461268186569214)
# ('දිනෙන්', 0.945125162601471)
# ('නියෝග', 0.944764256477356)

# %%
word2vec_cbow = Word2Vec(all_sentences, min_count=2, sg=1)
for word in test_words:
    sim_words = word2vec_cbow.wv.most_similar(word)
    print(word)
    print(*sim_words, sep="\n")
    print()
# Out:
# යුතු
# ('යුතුය', 0.8542492985725403)
# ('යුත්තේ', 0.8040897250175476)
# ('හැකි', 0.8024328947067261)
# ('හැක', 0.7615551352500916)
# ('යුතුව', 0.7563894391059875)
# ('හැක්කේ', 0.75618976354599)
# ('නොහැකි', 0.72788006067276)
# ('හැකිය', 0.7278342843055725)
# ('යුතුවේ', 0.7111713290214539)
# ('නියෝගයෙහි', 0.6846619248390198)
#
# මුදල්
# ('වන්දි', 0.6916292309761047)
# ('ක්\u200dරම', 0.6839450001716614)
# ('අත්තිකාරම්', 0.6794115900993347)
# ('ප්\u200dරවාහන', 0.6750259399414062)
# ('වියදම්', 0.6693071126937866)
# ('ගෙවීම', 0.6632765531539917)
# ('භාවිතය', 0.6531163454055786)
# ('සම්පාදන', 0.652567446231842)
# ('මධ්\u200dයසාර', 0.6470654010772705)
# ('ක්\u200dරමසම්පාදන', 0.6448792219161987)
#
# දින
# ('මාර්තු', 0.8301911354064941)
# ('තිබුණ', 0.823740541934967)
# ('අද', 0.8234764933586121)
# ('සඳහන්ව', 0.8156938552856445)
# ('ජුනි', 0.7879504561424255)
# ('මස', 0.7849934697151184)
# ('සිකුරාදා', 0.7846826910972595)
# ('යෝජනාවේ', 0.7833022475242615)
# ('රැස්වීම්', 0.7799726128578186)
# ('දෙසැම්බර්', 0.77949059009552)
#
# සඳහන්
# ('දැක්වෙන', 0.8741230964660645)
# ('සදහන්', 0.80132657289505)
# ('දැක්වේ', 0.7904355525970459)
# ('කී', 0.7729290723800659)
# ('වගන්තිවල', 0.7467016577720642)
# ('කරුණු', 0.7379187941551208)
# ('විස්තර', 0.7326687574386597)
# ('කොන්දේසි', 0.7300817966461182)
# ('කොන්දේසිවලට', 0.7263278961181641)
# ('විධිවිධානවලට', 0.7212526798248291)
#
# නිවාඩු
# ('අසනීප', 0.8450486063957214)
# ('නිවාඩුවක්', 0.8422274589538574)
# ('විවේක', 0.8390185832977295)
# ('අඩ', 0.8254193663597107)
# ('පඩි', 0.8109614253044128)
# ('නිවාඩුව', 0.7973483204841614)
# ('ඉකුත්', 0.7915072441101074)
# ('රහිත', 0.7905384302139282)
# ('නිලධරයෙකුට', 0.7861253023147583)
# ('වාසි', 0.7818225026130676)
#
# ලේකම්
# ('ප්\u200dරාදේශීය', 0.9207781553268433)
# ('කාර්යාලයේ', 0.9155516028404236)
# ('දිසාපති', 0.909994900226593)
# ('කාර්යාලය', 0.9097357392311096)
# ('මාතලේ', 0.9075066447257996)
# ('දිස්ත්\u200dරික්', 0.8964276909828186)
# ('කොට්ඨාශය', 0.891470193862915)
# ('පස්බාගේ', 0.8811882138252258)
# ('කොට්ඨාශයේ', 0.8800095915794373)
# ('කුරුණෑගල', 0.8799114227294922)
#
# කවරේද
# ('යන්න', 0.8160435557365417)
# ('එතුමා', 0.7902345061302185)
# ('මාර්ග', 0.7616999745368958)
# ('ප\u200d්\u200dරතිඵල', 0.7609385848045349)
# ('වාර්ෂිකව', 0.7595476508140564)
# ('යන්නත්', 0.7573831677436829)
# ('ලබන්නේද', 0.753016471862793)
# ('රට', 0.7521189451217651)
# ('ඒවායින්', 0.7496736645698547)
# ('කරන්නෙහිද', 0.7462102174758911)
#
# ජාතික
# ('ඒකාබද්ධතා', 0.7386569976806641)
# ('ආර්ථිකයේ', 0.7266825437545776)
# ('සමාජ', 0.7250111103057861)
# ('කිරුළ', 0.7151674628257751)
# ('වර්ධනයට', 0.7114647030830383)
# ('කරගත්තාවූ', 0.7111269235610962)
# ('ඒකාබද්ධතාවය', 0.7078205943107605)
# ('සතිය', 0.6954570412635803)
# ('මට්ටමේ', 0.6913952231407166)
# ('දැයට', 0.6910790205001831)
#
# වැටුප්
# ('වැටුප', 0.8263335227966309)
# ('වර්ධක', 0.7985722422599792)
# ('විශ්\u200dරාම', 0.7730019092559814)
# ('හිමි', 0.7615507245063782)
# ('පඩි', 0.7335294485092163)
# ('පරිමාණයේ', 0.7290884852409363)
# ('වැටුපක්', 0.7283743619918823)
# ('වාසි', 0.7190247774124146)
# ('වැටුපට', 0.7164431214332581)
# ('ආරම්භක', 0.7106515765190125)
#
# ඉදිරිපත්
# ('නියෝගය', 0.8567992448806763)
# ('ඉදිරිපත්කරන', 0.8340376019477844)
# ('දැන්වීම්', 0.8331853151321411)
# ('ඡායා', 0.8263381719589233)
# ('අමුණා', 0.8262711763381958)
# ('ඉල්ලුම්පත්\u200dරය', 0.8256304264068604)
# ('අයදුම්පත', 0.8239002823829651)
# ('ඉල්ලීම්', 0.8229495286941528)
# ('සහතිකයේ', 0.8216974139213562)
# ('ඉල්ලීමක්', 0.8176763653755188)

# %%
ft = fasttext.load_model("cc.si.300.bin")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
for word in test_words:
    sim_words = ft.get_nearest_neighbors(word)
    print(word)
    print(*sim_words, sep="\n")
    print()
# Out:
# යුතු
# (0.7585144639015198, 'හැකි')
# (0.7250702381134033, 'යුතුය')
# (0.6748450398445129, 'යුතුමුත්')
# (0.6698734760284424, 'යුතුම')
# (0.659508466720581, 'යුතුමව')
# (0.6580422520637512, 'යුතුයි.අවශ්\u200dය')
# (0.6556801795959473, 'යුතුමද')
# (0.6507406830787659, 'විය')
# (0.6501041054725647, 'නොහැකි')
# (0.6489912271499634, 'යුතුයැ’යි')
#
# මුදල්
# (0.6813880205154419, 'මුදල්හදල්')
# (0.670252799987793, 'මුදල්ගෙවා')
# (0.658108651638031, 'මුදල්ය')
# (0.6521779298782349, 'මුදල්ම')
# (0.6497461795806885, 'මුදල්මත')
# (0.6361136436462402, 'මුදලය')
# (0.6310645937919617, 'මුදල්වලට')
# (0.6301226615905762, 'මුදල්දී')
# (0.6195958852767944, 'මුදල්ද')
# (0.6072321534156799, 'මුදල්වත්')
#
# දින
# (0.5975547432899475, 'අගෝස්තු')
# (0.5897132754325867, 'මාර්තු')
# (0.5823441743850708, 'ජනවාරි')
# (0.5803649425506592, 'දිනයේයි')
# (0.5787533521652222, 'ජූලි')
# (0.5731720924377441, 'දිනයවූ')
# (0.5692654848098755, 'මැයි')
# (0.5682485699653625, 'දිනට')
# (0.5620603561401367, 'නොවැම්බර්')
# (0.5605639815330505, '1962.02.04')
#
# සඳහන්
# (0.6882578134536743, 'සඳහන්ඉඟි')
# (0.6669501662254333, 'සදහන්')
# (0.6621437668800354, 'සඳහන්කර')
# (0.6585769057273865, 'සඳහන්ද')
# (0.6530470848083496, 'සඳහන්කලා')
# (0.6503250598907471, 'සඳහන්ය.ඒ')
# (0.6477308869361877, 'සඳහන්වූ')
# (0.6417771577835083, 'සඳහනේ')
# (0.6407581567764282, 'සඳහන්වන')
# (0.6389496922492981, 'සඳහන්කළ')
#
# නිවාඩු
# (0.8121765851974487, 'නිවාඩුය')
# (0.7974015474319458, 'නිවාඩුද')
# (0.764424204826355, 'නිවාඩුනෙ')
# (0.7633227109909058, 'නිවාඩුනේ')
# (0.753150999546051, 'නිවාඩුත්')
# (0.7455112934112549, 'නිවාඩුයි')
# (0.7437388896942139, 'නිවාඩුදි')
# (0.7163406014442444, 'නිවාඩ')
# (0.7155945301055908, 'නිවාඩුවද')
# (0.7048909664154053, 'නිවාඩුකාලෙ')
#
# ලේකම්
# (0.7472834587097168, 'ලේකම්ය')
# (0.7417473196983337, 'ලේකම්ල')
# (0.7407518029212952, 'ලේකම්ගෙ')
# (0.7305315732955933, 'ලේකම්ද')
# (0.7098337411880493, 'ලේකම්කාර්යාලය')
# (0.7075890302658081, 'ලේකම්තුමිය')
# (0.7060631513595581, 'කාර්යාලයලේකම්')
# (0.704218327999115, 'මහ\u200cලේකම්')
# (0.7024929523468018, 'ලේකම්කම')
# (0.6980165243148804, 'ප්\u200dරා.ලේකම්')
#
# කවරේද
# (0.714691162109375, 'කවරේදැ')
# (0.6197257041931152, 'කියනුම')
# (0.5880873203277588, 'කවරේදැයි')
# (0.5810695290565491, 'හමාස')
# (0.5044190883636475, 'ආය්\u200dයසත්\u200dයය')
# (0.504011332988739, 'කිමෙක්ද')
# (0.4639665484428406, 'කවරේට')
# (0.46204251050949097, 'කෙසේද')
# (0.45945078134536743, 'දුක්ඛාර්\u200dය්\u200dයසත්\u200dයය')
# (0.45774540305137634, 'කිමෙක්')
#
# ජාතික
# (0.6294805407524109, 'උපජාතික')
# (0.5990524291992188, 'AMජාතික')
# (0.5876052975654602, 'ජාතිත')
# (0.581586480140686, 'ජාතික්')
# (0.5812414288520813, 'පාරජාතික')
# (0.5802926421165466, 'ලංකාජාතික')
# (0.580190896987915, 'එක්සත්ජාතික')
# (0.5750151872634888, 'සුදුජාතික')
# (0.5700624585151672, 'නෑ.ජාතික')
# (0.5698245167732239, 'එක්සත්')
#
# වැටුප්
# (0.7703861594200134, 'වැටුප්ද')
# (0.7497496604919434, 'වැටුප්ය')
# (0.7120479345321655, 'වැටුප්තල')
# (0.7069556713104248, 'වැටුපේ')
# (0.7061773538589478, 'වැටුපද')
# (0.6916297078132629, 'වැටුපයි')
# (0.6829730272293091, 'වැටුපත්')
# (0.6819652915000916, 'වැටුපකි')
# (0.6790965795516968, 'වැටුප්දීමනා')
# (0.6700196862220764, 'වැටුප්වලට')
#
# ඉදිරිපත්
# (0.6468639373779297, 'iඉදිරිපත්')
# (0.6435003876686096, 'ඉදිරිපත්කළා')
# (0.6283656358718872, 'ඉදිරිපත්කලා')
# (0.6136042475700378, 'ඉදිරිපත්කළ')
# (0.6064459085464478, 'ඉදිරිපත්කර')
# (0.6060041785240173, 'ඉදිරිපත්කල')
# (0.6035129427909851, 'ඉදිරිපත්කරන්න')
# (0.6033950448036194, 'ඉදිරිපත්කලේය')
# (0.5979558825492859, 'මතයි.ඉදිරිපත්')
# (0.5976380705833435, 'අදිරිපත්')

# %%
ftvec = KeyedVectors.load_word2vec_format('cc.si.300.vec', binary=False)

# %%
for word in test_words:
    sim_words = ftvec.most_similar(word)
    print(word)
    print(*sim_words, sep="\n")
    print()
# Out:
# යුතු
# ('හැකි', 0.758513331413269)
# ('යුතුය', 0.7250239849090576)
# ('යුතුමුත්', 0.6748719811439514)
# ('යුතුම', 0.669881284236908)
# ('යුතුමව', 0.6594510674476624)
# ('යුතුයි.අවශ්\u200dය', 0.6580855250358582)
# ('යුතුමද', 0.6557757258415222)
# ('විය', 0.65071702003479)
# ('නොහැකි', 0.6500844359397888)
# ('යුතුයැ’යි', 0.6491255164146423)
#
# මුදල්
# ('මුදල්හදල්', 0.6814319491386414)
# ('මුදල්ගෙවා', 0.6704550385475159)
# ('මුදල්ය', 0.6580941677093506)
# ('මුදල්ම', 0.6521395444869995)
# ('මුදල්මත', 0.6496994495391846)
# ('මුදලය', 0.6362110376358032)
# ('මුදල්වලට', 0.631045937538147)
# ('මුදල්දී', 0.6302124261856079)
# ('මුදල්ද', 0.6196855902671814)
# ('මුදල්වත්', 0.6071982979774475)
#
# දින
# ('අගෝස්තු', 0.5975399017333984)
# ('මාර්තු', 0.58966463804245)
# ('ජනවාරි', 0.5822768807411194)
# ('දිනයේයි', 0.5804850459098816)
# ('ජූලි', 0.5787363648414612)
# ('දිනයවූ', 0.5730636119842529)
# ('මැයි', 0.5692448616027832)
# ('දිනට', 0.5682713389396667)
# ('නොවැම්බර්', 0.5620465874671936)
# ('1962.02.04', 0.56041419506073)
#
# සඳහන්
# ('සඳහන්ඉඟි', 0.6883292198181152)
# ('සදහන්', 0.6669554710388184)
# ('සඳහන්කර', 0.662214457988739)
# ('සඳහන්ද', 0.658584713935852)
# ('සඳහන්කලා', 0.6528692245483398)
# ('සඳහන්ය.ඒ', 0.6502663493156433)
# ('සඳහන්වූ', 0.6477637887001038)
# ('සඳහනේ', 0.6417644023895264)
# ('සඳහන්වන', 0.6408218741416931)
# ('සඳහන්කළ', 0.6389565467834473)
#
# නිවාඩු
# ('නිවාඩුය', 0.8121082186698914)
# ('නිවාඩුද', 0.7973071932792664)
# ('නිවාඩුනෙ', 0.7644287347793579)
# ('නිවාඩුනේ', 0.7632619142532349)
# ('නිවාඩුත්', 0.7531595230102539)
# ('නිවාඩුයි', 0.7454591989517212)
# ('නිවාඩුදි', 0.7436092495918274)
# ('නිවාඩ', 0.7163293957710266)
# ('නිවාඩුවද', 0.7156201601028442)
# ('නිවාඩුකාලෙ', 0.7049460411071777)
#
# ලේකම්
# ('ලේකම්ය', 0.7473382949829102)
# ('ලේකම්ල', 0.7417590618133545)
# ('ලේකම්ගෙ', 0.7407247424125671)
# ('ලේකම්ද', 0.7305183410644531)
# ('ලේකම්කාර්යාලය', 0.7098091840744019)
# ('ලේකම්තුමිය', 0.707619845867157)
# ('කාර්යාලයලේකම්', 0.7061454653739929)
# ('මහ\u200cලේකම්', 0.7042863965034485)
# ('ලේකම්කම', 0.7025462985038757)
# ('ප්\u200dරා.ලේකම්', 0.6980292797088623)
#
# කවරේද
# ('කවරේදැ', 0.7146962285041809)
# ('කියනුම', 0.6197346448898315)
# ('කවරේදැයි', 0.5881251692771912)
# ('හමාස', 0.5810121297836304)
# ('ආය්\u200dයසත්\u200dයය', 0.5044548511505127)
# ('කිමෙක්ද', 0.503998875617981)
# ('කවරේට', 0.464020311832428)
# ('කෙසේද', 0.46204254031181335)
# ('දුක්ඛාර්\u200dය්\u200dයසත්\u200dයය', 0.4593966603279114)
# ('කිමෙක්', 0.4577503502368927)
#
# ජාතික
# ('උපජාතික', 0.6293835043907166)
# ('AMජාතික', 0.5990393161773682)
# ('ජාතිත', 0.5875296592712402)
# ('ජාතික්', 0.5816394686698914)
# ('පාරජාතික', 0.5812163352966309)
# ('ලංකාජාතික', 0.5801467895507812)
# ('එක්සත්ජාතික', 0.5801339745521545)
# ('සුදුජාතික', 0.5751017928123474)
# ('නෑ.ජාතික', 0.5699623823165894)
# ('එක්සත්', 0.569839596748352)
#
# වැටුප්
# ('වැටුප්ද', 0.7704083919525146)
# ('වැටුප්ය', 0.7497021555900574)
# ('වැටුප්තල', 0.7119963765144348)
# ('වැටුපේ', 0.70694500207901)
# ('වැටුපද', 0.7061805725097656)
# ('වැටුපයි', 0.6916345953941345)
# ('වැටුපත්', 0.6830534934997559)
# ('වැටුපකි', 0.6819068193435669)
# ('වැටුප්දීමනා', 0.6791043281555176)
# ('වැටුප්වලට', 0.6701265573501587)
#
# ඉදිරිපත්
# ('iඉදිරිපත්', 0.6469913125038147)
# ('ඉදිරිපත්කළා', 0.6435180902481079)
# ('ඉදිරිපත්කලා', 0.6283477544784546)
# ('ඉදිරිපත්කළ', 0.6136922240257263)
# ('ඉදිරිපත්කර', 0.6063425540924072)
# ('ඉදිරිපත්කල', 0.6059906482696533)
# ('ඉදිරිපත්කරන්න', 0.6036534309387207)
# ('ඉදිරිපත්කලේය', 0.6031646132469177)
# ('මතයි.ඉදිරිපත්', 0.5978697538375854)
# ('අදිරිපත්', 0.5975160598754883)
